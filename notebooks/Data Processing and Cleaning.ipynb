# %%
import pandas as pd

# %% [markdown]
# ### Data Processing and Cleaning
#
# (Problem 3. Data cleaning and preprocessing)

# %%
asthma_dataset = pd.read_csv('../data/asthma_disease_data.csv')

# %%
pd.set_option('display.max_columns', None)
asthma_dataset.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       5034   63       0          1               0  15.848744        0
# 1       5035   26       1          2               2  22.757042        0
# 2       5036   57       0          2               1  18.395396        0
# 3       5037   40       1          2               1  38.515278        0
# 4       5038   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  PollutionExposure  \
# 0          0.894448     5.488696      8.701003           7.388481
# 1          5.897329     6.341014      5.153966           1.969838
# 2          6.739367     9.196237      6.840647           1.460593
# 3          1.404503     5.826532      4.253036           0.581905
# 4          4.604493     3.127048      9.625799           0.980875
#
#    PollenExposure  DustExposure  PetAllergy  FamilyHistoryAsthma  \
# ...

# %%
asthma_dataset.DoctorInCharge.value_counts()
# Out:
# DoctorInCharge
# Dr_Confid    2392
# Name: count, dtype: int64

# %% [markdown]
# This variable onlhy contains one value, the entropy is too small and the column brings no value for the analysis. We can drop it completely or just ignore it during the analysis, but dropping it is easier.

# %%
asthma_dataset = asthma_dataset.drop('DoctorInCharge', axis=1)
asthma_dataset.columns
# Out:
# Index(['PatientID', 'Age', 'Gender', 'Ethnicity', 'EducationLevel', 'BMI',
#        'Smoking', 'PhysicalActivity', 'DietQuality', 'SleepQuality',
#        'PollutionExposure', 'PollenExposure', 'DustExposure', 'PetAllergy',
#        'FamilyHistoryAsthma', 'HistoryOfAllergies', 'Eczema', 'HayFever',
#        'GastroesophagealReflux', 'LungFunctionFEV1', 'LungFunctionFVC',
#        'Wheezing', 'ShortnessOfBreath', 'ChestTightness', 'Coughing',
#        'NighttimeSymptoms', 'ExerciseInduced', 'Diagnosis'],
#       dtype='object')
